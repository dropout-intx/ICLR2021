# %%
from sklearn.datasets import fetch_20newsgroups
from keras.layers import  Dropout, Dense
from keras.models import Sequential
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn import metrics

# %%
def TFIDF(X_train, X_test, MAX_NB_WORDS=1000): # was 75000
    vectorizer_x = TfidfVectorizer(max_features=MAX_NB_WORDS)
    X_train = vectorizer_x.fit_transform(X_train).toarray()
    X_test = vectorizer_x.transform(X_test).toarray()
    print("tf-idf with",str(np.array(X_train).shape[1]),"features")
    return (X_train,X_test)

# %%
from tensorflow.keras.optimizers import Adam
def Build_Model_DNN_Text(shape, nClasses, dropout=0.5):
    """
    buildModel_DNN_Tex(shape, nClasses,dropout)
    Build Deep neural networks Model for text classification
    Shape is input feature space
    nClasses is number of classes
    """
    model = Sequential()
    node = 512 # number of nodes
    nLayers = 4 # number of  hidden layer
    model.add(Dense(node,input_dim=shape,activation='relu'))
    model.add(Dropout(dropout))
    for i in range(0, nLayers):
        model.add(Dense(node,input_dim=node,activation='relu'))
        model.add(Dropout(dropout))
    model.add(Dense(nClasses, activation='softmax'))
    opt = Adam(learning_rate=0.001*(1+dropout), beta_1=0.9,
                                   beta_2=0.999, epsilon=1e-07, amsgrad=False, name='Adam')
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model

# %%
newsgroups_train = fetch_20newsgroups(subset='train')
newsgroups_test = fetch_20newsgroups(subset='test')
n_samples = 1000
X_train = np.array(newsgroups_train.data[:n_samples])
X_test = np.array(newsgroups_test.data[:n_samples])
y_train = newsgroups_train.target[:n_samples]
y_test = newsgroups_test.target[:n_samples]

# %%
from sklearn.model_selection import train_test_split
X_train_tfidf, X_test_tfidf = TFIDF(X_train, X_test)
X_train_tfidf, X_val_tfidf, y_train, y_val = train_test_split(X_train_tfidf, y_train, test_size=0.2)
# Out:
# tf-idf with 1000 features

# %%
# Add 3 columns
order = 1
for i in range(order):
    X_train_tfidf = np.hstack((X_train_tfidf, np.random.uniform(0, 1, size=(X_train_tfidf.shape[0], 1))))
    X_val_tfidf = np.hstack((X_val_tfidf, np.random.uniform(0, 1, size=(X_val_tfidf.shape[0], 1))))
    X_test_tfidf = np.hstack((X_test_tfidf, np.random.uniform(0, 1, size=(X_test_tfidf.shape[0], 1))))

idx_train = X_train_tfidf[:, -1] > -1
idx_val   = X_val_tfidf[:, -1] > -1
idx_test  = X_test_tfidf[:, -1] > -1
thresh = 0.7**order
for i in range(1, order+1):
    idx_train = np.logical_and(idx_train, X_train_tfidf[:, -i] > thresh)
    idx_val   = np.logical_and(idx_val, X_val_tfidf[:, -i] > thresh)
    idx_test  = np.logical_and(idx_test, X_test_tfidf[:, -i] > thresh)
y_train[idx_train] = 21
y_val[idx_val] = 21
y_test[idx_test] = 21
"""
if order == 3:
    y_train[np.logical_and(
                np.logical_and(X_train_tfidf[:, -1]>0.5, X_train_tfidf[:, -2]>0.5),
        X_train_tfidf[:, -3] > 0.5)
        ] = 21
    y_val[np.logical_and(
                np.logical_and(X_val_tfidf[:, -1]>0.5, X_val_tfidf[:, -2]>0.5),
        X_val_tfidf[:, -3] > 0.5)] = 21
    y_test[np.logical_and(
                np.logical_and(X_test_tfidf[:, -1]>0.5, X_test_tfidf[:, -2]>0.5),
        X_test_tfidf[:, -3] > 0.5)] = 21
elif order == 1:
    y_train[X_train_tfidf[:, -1]>0.5] = 21
    y_val[X_val_tfidf[:, -1]>0.5] = 21
    y_test[X_test_tfidf[:, -1]>0.5] = 21
"""
# Out:
# '\nif order == 3:\n    y_train[np.logical_and(\n                np.logical_and(X_train_tfidf[:, -1]>0.5, X_train_tfidf[:, -2]>0.5),\n        X_train_tfidf[:, -3] > 0.5)\n        ] = 21\n    y_val[np.logical_and(\n                np.logical_and(X_val_tfidf[:, -1]>0.5, X_val_tfidf[:, -2]>0.5),\n        X_val_tfidf[:, -3] > 0.5)] = 21\n    y_test[np.logical_and(\n                np.logical_and(X_test_tfidf[:, -1]>0.5, X_test_tfidf[:, -2]>0.5),\n        X_test_tfidf[:, -3] > 0.5)] = 21\nelif order == 1:\n    y_train[X_train_tfidf[:, -1]>0.5] = 21\n    y_val[X_val_tfidf[:, -1]>0.5] = 21\n    y_test[X_test_tfidf[:, -1]>0.5] = 21\n'

# %%
print(np.max(y_train))
# Out:
# 21

# %%
from xgboost import XGBRegressor as xgb
from sklearn.multioutput import MultiOutputRegressor
import tensorflow as tf
max_epoch = 50
nClasses = np.max(y_train) + 1
with open("results/results_newsgroups_modified_{}.tsv".format(order), 'w') as results_file:
    for fit_iter in range(5):
        for dropout_rate in [0.0, 0.125, 0.25, 0.375, 0.5, 0.625]:
            model = Build_Model_DNN_Text(X_train_tfidf.shape[1], nClasses, dropout_rate)
            epoch = 0
            while epoch <= max_epoch:
                print(dropout_rate, fit_iter, epoch)
                pred_train = model.predict(X_train_tfidf)#.numpy()
                #pred_val  = model.predict(X_val_tfidf)#.numpy()
                pred_test = model.predict(X_test_tfidf)#.numpy()
                
                def fit_and_predict(depth, X_train, y_train, X_test, y_test):
                    my_xgbs = [xgb(max_depth=depth, n_estimators=1000) for _ in range(nClasses)]
                    for i in range(len(my_xgbs)):
                        print(i, end='\r')
                        my_xgbs[i].fit(X_train, y_train, early_stopping_rounds=10,
                                                     eval_set=[(X_test, y_test)],
                                verbose=False
                        )
                    xgb_preds = np.array([x.predict(X_train_tfidf) for x in my_xgbs]).T
                    xgb_test_preds = np.array([x.predict(X_test_tfidf) for x in my_xgbs]).T
                    return my_xgbs, xgb_preds, xgb_test_preds
                
                xgb1s, xgb1_preds, xgb1_test_preds = fit_and_predict(
                    1, X_train_tfidf, pred_train, X_test_tfidf, pred_test)
                
                xgb2s, xgb2_preds, xgb2_test_preds = fit_and_predict(
                    2, X_train_tfidf, pred_train-xgb1_preds, X_test_tfidf, pred_test-xgb1_test_preds)
                
                #xgb3s, xgb3_preds, xgb3_test_preds = fit_and_predict(
                #    3, X_train_tfidf, pred_train-xgb1_preds-xgb2_preds, X_test_tfidf, pred_test-xgb1_test_preds-xgb2_test_preds)

                xgb1_var = np.var(xgb1_test_preds)
                xgb2_var = np.var(xgb2_test_preds)# - xgb1_preds)
                xgb3_var = np.var(pred_test - xgb1_test_preds - xgb2_test_preds)# - xgb2_preds)
                
                train_acc = np.mean(y_train == np.argmax(model.predict(X_train_tfidf), axis=1))
                query_acc = np.mean(y_test == np.argmax(model.predict(X_test_tfidf), axis=1))
                
                train_acc_one = np.mean(y_train[y_train == 21] == np.argmax(model.predict(X_train_tfidf), axis=1)[y_train == 21])
                query_acc_one = np.mean(y_test[y_test == 21] == np.argmax(model.predict(X_test_tfidf), axis=1)[y_test == 21])
                
                #test_preds = 
                #print([model.predict(X_test_tfidf)[:, y_test])
                train_sq  = np.mean(tf.nn.sparse_softmax_cross_entropy_with_logits(y_train, model.predict(X_train_tfidf)))
                test_sq  = np.mean(tf.nn.sparse_softmax_cross_entropy_with_logits(y_test, model.predict(X_test_tfidf)))
                #test_sq   = np.mean((1.0 - tf.nn.softmax(model.predict(X_test_tfidf)[:, y_test]))**2)

                print(xgb1_var, xgb2_var, xgb3_var, train_acc, query_acc, train_sq, test_sq, train_acc_one, query_acc_one)
                print('{:.3f}\t{:d}\t{:d}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}'.format(
                        dropout_rate, fit_iter, epoch,
                        xgb1_var, xgb2_var, xgb3_var, train_acc, query_acc,
                    train_sq, test_sq, train_acc_one, query_acc_one),
                      file=results_file, flush=True)

                if epoch < 10: 
                    model.fit(X_train_tfidf, y_train,
                              validation_data=(X_val_tfidf, y_val),
                              epochs=5,
                              batch_size=128,
                              verbose=2)
                    epoch += 5
                else:
                    if epoch <= max_epoch:
                        model.fit(X_train_tfidf, y_train,
                                  validation_data=(X_val_tfidf, y_val),
                                  epochs=10,
                                  batch_size=128,
                                  verbose=0)
                    epoch += 10
# Out:
# 0.0 0 0
# 3.8765053e-09 7.937654e-09 2.560359e-07 0.035 0.038 3.0911224 3.0911298 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8922 - accuracy: 0.2650 - val_loss: 2.6101 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5660 - accuracy: 0.3088 - val_loss: 2.5380 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3848 - accuracy: 0.3088 - val_loss: 2.3871 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2285 - accuracy: 0.3125 - val_loss: 2.3438 - val_accuracy: 0.3150
# Epoch 5/5
#  - 0s - loss: 2.1443 - accuracy: 0.3438 - val_loss: 2.3544 - val_accuracy: 0.3200
# 0.0 0 5
# 0.00050775625 0.0013514793 0.018037694 0.3475 0.333 2.803844 2.8312452 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.0881 - accuracy: 0.3550 - val_loss: 2.2811 - val_accuracy: 0.3100
# Epoch 2/5
#  - 0s - loss: 2.0144 - accuracy: 0.3650 - val_loss: 2.4030 - val_accuracy: 0.3400
# Epoch 3/5
#  - 0s - loss: 1.8186 - accuracy: 0.4437 - val_loss: 2.1863 - val_accuracy: 0.3350
# Epoch 4/5
#  - 0s - loss: 1.4577 - accuracy: 0.5400 - val_loss: 2.1689 - val_accuracy: 0.4100
# Epoch 5/5
#  - 0s - loss: 1.1361 - accuracy: 0.6087 - val_loss: 2.9905 - val_accuracy: 0.3800
# 0.0 0 10
# 0.0008557798 0.0016418176 0.0262149 0.5975 0.373 2.6277564 2.7907906 1.0 0.8679867986798679
# 0.0 0 20
0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8729 - accuracy: 0.2675 - val_loss: 2.7157 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5611 - accuracy: 0.3088 - val_loss: 2.4853 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3633 - accuracy: 0.3088 - val_loss: 2.3702 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2216 - accuracy: 0.3088 - val_loss: 2.3264 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1395 - accuracy: 0.3150 - val_loss: 2.3116 - val_accuracy: 0.3350
# 0.0 1 5
# 0.0005176189 0.0013707589 0.01718212 0.3575 0.34 2.8043566 2.8357174 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.0861 - accuracy: 0.3675 - val_loss: 2.2535 - val_accuracy: 0.3600
# Epoch 2/5
#  - 0s - loss: 1.9786 - accuracy: 0.3887 - val_loss: 2.1807 - val_accuracy: 0.3600
# Epoch 3/5
#  - 0s - loss: 1.7415 - accuracy: 0.4600 - val_loss: 2.2441 - val_accuracy: 0.3550
# Epoch 4/5
#  - 0s - loss: 1.4324 - accuracy: 0.5163 - val_loss: 2.4773 - val_accuracy: 0.3950
# Epoch 5/5
#  - 0s - loss: 1.0598 - accuracy: 0.6338 - val_loss: 2.7651 - val_accuracy: 0.4200
# 0.0 1 10
# 0.001266388 0.0020021824 0.02614325 0.67 0.391 2.570431 2.8010523 1.0 0.8184818481848185
# 0.0 1 20
# 0.0010258198 0.0017905964 0.039929643 0.995 0.413 2.1765027 2.7572448 1.0 0.768976897689769
# 0.0 1 30
# 0.000996585 0.0018805824 0.040823855 1.0 0.381 2.1676683 2.776803 1.0 0.6765676567656765
# 0.0 1 40
# 0.0009966375 0.0020621547 0.04167575 1.0 0.402 2.1664207 2.7626336 1.0 0.7392739273927392
# 0.0 1 50
# 0.0009967104 0.0017070902 0.041553263 1.0 0.416 2.166338 2.7541645 1.0 0.7557755775577558
# 0.125 1 0
# 1.10794e-09 2.0027138e-09 1.6413364e-07 0.03375 0.034 3.0911443 3.091152 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8499 - accuracy: 0.2750 - val_loss: 2.6192 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5024 - accuracy: 0.3088 - val_loss: 2.4489 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.2962 - accuracy: 0.3088 - val_loss: 2.2884 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.1653 - accuracy: 0.3088 - val_loss: 2.2711 - val_accuracy: 0.3200
# Epoch 5/5
#  - 0s - loss: 2.1238 - accuracy: 0.3350 - val_loss: 2.2984 - val_accuracy: 0.3250
# 0.125 1 5
# 0.0005180144 0.001234695 0.014789032 0.355 0.33 2.8042383 2.8591378 1.0 0.9801980198019802
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1014 - accuracy: 0.3537 - val_loss: 2.3672 - val_accuracy: 0.3350
# Epoch 2/5
#  - 0s - loss: 2.0740 - accuracy: 0.3663 - val_loss: 2.3883 - val_accuracy: 0.3050
# Epoch 3/5
#  - 0s - loss: 2.0368 - accuracy: 0.3787 - val_loss: 2.3830 - val_accuracy: 0.2900
# Epoch 4/5
#  - 0s - loss: 1.9227 - accuracy: 0.3913 - val_loss: 2.3453 - val_accuracy: 0.3300
# Epoch 5/5
#  - 0s - loss: 1.7172 - accuracy: 0.4475 - val_loss: 2.3132 - val_accuracy: 0.3200
# 0.125 1 10
- val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1553 - accuracy: 0.3137 - val_loss: 2.3225 - val_accuracy: 0.3250
# 0.0 3 5
# 0.0005109041 0.0013121358 0.01681968 0.36 0.323 2.8055909 2.8386695 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1078 - accuracy: 0.3663 - val_loss: 2.2862 - val_accuracy: 0.3300
# Epoch 2/5
#  - 0s - loss: 2.0590 - accuracy: 0.4038 - val_loss: 2.4181 - val_accuracy: 0.3550
# Epoch 3/5
#  - 0s - loss: 1.9577 - accuracy: 0.4125 - val_loss: 2.3030 - val_accuracy: 0.3600
# Epoch 4/5
#  - 0s - loss: 1.7536 - accuracy: 0.4712 - val_loss: 2.3594 - val_accuracy: 0.3450
# Epoch 5/5
#  - 0s - loss: 1.4707 - accuracy: 0.5325 - val_loss: 2.1687 - val_accuracy: 0.3750
# 0.0 3 10
# 0.00052390166 0.0011590603 0.01831567 0.56625 0.335 2.6583967 2.845094 1.0 0.7755775577557755
# 0.0 3 20
# 0.0009780234 0.0017136786 0.035842057 0.99 0.374 2.1879616 2.7949889 0.9919028340080972 0.5775577557755776
# 0.0 3 30
# 0.0009951466 0.0017036601 0.037857275 1.0 0.421 2.1670077 2.745312 1.0 0.7128712871287128
# 0.0 3 40
# 0.000996072 0.0017056607 0.03862555 1.0 0.421 2.1664991 2.7451482 1.0 0.7029702970297029
# 0.0 3 50
# 0.000996287 0.001706914 0.03903191 1.0 0.426 2.1663892 2.7440045 1.0 0.7062706270627063
# 0.125 3 0
# 1.9144757e-09 4.9630384e-09 2.3869146e-07 0.03375 0.045 3.0912156 3.0912066 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.9159 - accuracy: 0.2650 - val_loss: 2.5878 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.6185 - accuracy: 0.3088 - val_loss: 2.5110 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.4409 - accuracy: 0.3088 - val_loss: 2.4774 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2917 - accuracy: 0.3088 - val_loss: 2.3212 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1963 - accuracy: 0.3088 - val_loss: 2.3224 - val_accuracy: 0.3000
# 0.125 3 5
# 0.0005198933 0.001395938 0.016665457 0.30875 0.303 2.8076372 2.8426197 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1375 - accuracy: 0.3162 - val_loss: 2.3046 - val_accuracy: 0.3300
# Epoch 2/5
#  - 0s - loss: 2.1190 - accuracy: 0.3650 - val_loss: 2.2890 - val_accuracy: 0.3300
# Epoch 3/5
#  - 0s - loss: 2.0931 - accuracy: 0.3462 - val_loss: 2.4001 - val_accuracy: 0.3300
# Epoch 4/5
#  - 0s - loss: 2.0614 - accuracy: 0.3487 - val_loss: 2.3410 - val_accuracy: 0.3250
# Epoch 5/5
#  - 0s - loss: 2.0185 - accuracy: 0.3713 - val_loss: 2.3545 - val_accuracy: 0.3300
# 0.125 3 10
# 0.00055159995 0.0012215774 0.013931638 0.38375 0.308 2.7910023 2.8746939 1.0 0.8910891089108911
# 0.125 3 20
# 0.00090200466 0.0018297726 0.03205943 0.93625 0.355 2.2749767 2.818592 0.9878542510121457 0.570957095709571
# 0.125 3 30
# 0.0009963617 0.0014857755 0.038679797 1.0 0.411 2.1685097 2.7525733 1.0 0.6798679867986799
# 0.125 3 40
# 0.00097309804 0.0018072058 0.039522007 1.0 0.453 2.1677732 2.7211587 1.0 0.7755775577557755
# 0.125 3 50
# 0.0009739889 0.0018636276 0.040322334 1.0 0.41 2.1663172 2.7519612 1.0 0.6765676567656765
# 0.25 3 0
# 1.7692093e-09 3.8903654e-09 1.740539e-07 0.07375 0.067 3.090868 3.0908637 0.13360323886639677 0.13861386138613863
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8503 - accuracy: 0.2650 - val_loss: 2.6508 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5603 - accuracy: 0.3088 - val_loss: 2.4783 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3535 - accuracy: 0.3088 - val_loss: 2.3887 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2493 - accuracy: 0.3088 - val_loss: 2.3122 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1538 - accuracy: 0.3088 - val_loss: 2.3084 - val_accuracy: 0.3000
# 0.25 3 5
# 0.00051317335 0.0013593083 0.014103979 0.30875 0.303 2.8079858 2.865234 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1256 - accuracy: 0.3100 - val_loss: 2.3459 - val_accuracy: 0.3200
# Epoch 2/5
#  - 0s - loss: 2.1102 - accuracy: 0.3375 - val_loss: 2.3522 - val_accuracy: 0.3350
# Epoch 3/5
#  - 0s - loss: 2.0849 - accuracy: 0.3625 - val_loss: 2.4147 - val_accuracy: 0.3200
# Epoch 4/5
#  - 0s - loss: 2.0420 - accuracy: 0.3725 - val_loss: 2.5260 - val_accuracy: 0.3450
# Epoch 5/5
#  - 0s - loss: 1.9457 - accuracy: 0.3913 - val_loss: 2.4374 - val_accuracy: 0.3150
# 0.25 3 10
# 0.0012229092 0.0028180277 0.018390471 0.44 0.308 2.755866 2.8818624 1.0 0.7788778877887789
# 0.25 3 20
# 0.00085754873 0.0017656127 0.032408062 0.93 0.417 2.3127837 2.7535837 1.0 0.834983498349835
# 0.25 3 30
# 0.0009431814 0.0020317421 0.039256398 0.99375 0.449 2.1850193 2.7224593 1.0 0.9141914191419142
# 0.25 3 40
# 0.0010383839 0.0017374696 0.03900041 1.0 0.446 2.1667886 2.7351139 1.0 0.7161716171617162
# 0.25 3 50
# 0.0010414082 0.0017983154 0.041214075 1.0 0.439 2.1662989 2.7280977 1.0 0.7953795379537953
# 0.375 3 0
# 3.3186325e-09 7.573456e-09 3.3205853e-07 0.04125 0.037 3.0909753 3.0909634 0.004048582995951417 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8436 - accuracy: 0.2713 - val_loss: 2.6543 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5724 - accuracy: 0.3088 - val_loss: 2.5078 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3921 - accuracy: 0.3088 - val_loss: 2.3553 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2355 - accuracy: 0.3088 - val_loss: 2.3116 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1663 - accuracy: 0.3088 - val_loss: 2.2656 - val_accuracy: 0.3000
# 0.375 3 5
# 0.0005025982 0.0013389017 0.013657166 0.30875 0.303 2.8073795 2.8687077 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1358 - accuracy: 0.3100 - val_loss: 2.3219 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.1243 - accuracy: 0.3125 - val_loss: 2.3101 - val_accuracy: 0.3150
# Epoch 3/5
#  - 0s - loss: 2.1138 - accuracy: 0.3462 - val_loss: 2.3128 - val_accuracy: 0.3050
# Epoch 4/5
#  - 0s - loss: 2.0913 - accuracy: 0.3575 - val_loss: 2.3168 - val_accuracy: 0.3050
# Epoch 5/5
#  - 0s - loss: 2.0799 - accuracy: 0.3587 - val_loss: 2.3446 - val_accuracy: 0.3050
# 0.375 3 10
- val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.2061 - accuracy: 0.3088 - val_loss: 2.3488 - val_accuracy: 0.3300
# Epoch 3/5
#  - 0s - loss: 2.1729 - accuracy: 0.3125 - val_loss: 2.3120 - val_accuracy: 0.3250
# Epoch 4/5
#  - 0s - loss: 2.1424 - accuracy: 0.3162 - val_loss: 2.3107 - val_accuracy: 0.3200
# Epoch 5/5
#  - 0s - loss: 2.1376 - accuracy: 0.3325 - val_loss: 2.3530 - val_accuracy: 0.3050
# 0.625 3 10
# 0.0005158965 0.0012897074 0.0110239675 0.355 0.319 2.80667 2.9146402 1.0 0.9273927392739274
# 0.625 3 20
# 0.0005221229 0.0011966419 0.015759185 0.36375 0.318 2.7936907 2.8596148 1.0 0.9141914191419142
# 0.625 3 30
# 0.000878702 0.0016657496 0.0145851355 0.4825 0.275 2.735258 2.9041846 0.9959514170040485 0.7194719471947195
# 0.625 3 40
# 0.0010863191 0.0020738908 0.021262443 0.495 0.322 2.685345 2.848951 1.0 0.8811881188118812
# 0.625 3 50
# 0.0010969845 0.00169916 0.017778989 0.575 0.291 2.6285431 2.8880692 1.0 0.7062706270627063
# 0.0 4 0
# 2.9327767e-09 6.8200667e-09 1.9005321e-07 0.03625 0.026 3.090935 3.0909364 0.020242914979757085 0.006600660066006601
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.9151 - accuracy: 0.2562 - val_loss: 2.6115 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5717 - accuracy: 0.3088 - val_loss: 2.5196 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3748 - accuracy: 0.3088 - val_loss: 2.4020 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2278 - accuracy: 0.3088 - val_loss: 2.3305 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1449 - accuracy: 0.3462 - val_loss: 2.3969 - val_accuracy: 0.3400
# 0.0 4 5
# 0.0005233224 0.0012511086 0.018563442 0.3575 0.334 2.804353 2.8286066 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.0919 - accuracy: 0.3587 - val_loss: 2.3139 - val_accuracy: 0.3300
# Epoch 2/5
#  - 0s - loss: 2.0488 - accuracy: 0.3663 - val_loss: 2.4155 - val_accuracy: 0.3450
# Epoch 3/5
#  - 0s - loss: 1.9368 - accuracy: 0.4038 - val_loss: 2.3862 - val_accuracy: 0.2950
# Epoch 4/5
#  - 0s - loss: 1.6631 - accuracy: 0.4613 - val_loss: 2.3142 - val_accuracy: 0.3450
# Epoch 5/5
#  - 0s - loss: 1.3204 - accuracy: 0.5387 - val_loss: 2.2632 - val_accuracy: 0.3800
# 0.0 4 10
# 0.00050659454 0.001160198 0.017337898 0.61875 0.347 2.6459394 2.8523383 0.9878542510121457 0.6765676567656765
# 0.0 4 20
# 0.0009916229 0.0018398439 0.037857715 0.99875 0.442 2.1771543 2.7215796 1.0 0.8547854785478548
# 0.0 4 30
# 0.0009962429 0.0017051328 0.039057583 1.0 0.429 2.1667733 2.7325294 1.0 0.7722772277227723
# 0.0 4 40
# 0.0009963727 0.0017057173 0.039348915 1.0 0.431 2.166513 2.7353451 1.0 0.759075907590759
# 0.0 4 50
# 0.0009964698 0.0017068707 0.03958278 1.0 0.43 2.1664197 2.7360697 1.0 0.7557755775577558
# 0.125 4 0
# 9.943415e-10 1.7765472e-09 1.4278469e-07 0.03125 0.029 3.0912457 3.0912542 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.9227 - accuracy: 0.2537 - val_loss: 2.6198 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5411 - accuracy: 0.3088 - val_loss: 2.5283 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3402 - accuracy: 0.3088 - val_loss: 2.3643 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2090 - accuracy: 0.3088 - val_loss: 2.2860 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1395 - accuracy: 0.3088 - val_loss: 2.2838 - val_accuracy: 0.3000
# 0.125 4 5
# 0.0005183498 0.0011834622 0.015238392 0.30875 0.303 2.8052819 2.8500168 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1209 - accuracy: 0.3212 - val_loss: 2.3029 - val_accuracy: 0.3150
# Epoch 2/5
#  - 0s - loss: 2.0934 - accuracy: 0.3625 - val_loss: 2.3264 - val_accuracy: 0.2950
# Epoch 3/5
#  - 0s - loss: 2.0585 - accuracy: 0.3650 - val_loss: 2.3753 - val_accuracy: 0.2950
# Epoch 4/5
#  - 0s - loss: 1.9661 - accuracy: 0.3913 - val_loss: 2.4477 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 1.7519 - accuracy: 0.4350 - val_loss: 2.5782 - val_accuracy: 0.3100
# 0.125 4 10
# 0.0006265563 0.0011895862 0.013205439 0.485 0.272 2.7357142 2.9268913 0.9959514170040485 0.5643564356435643
# 0.125 4 20
# 0.0008284142 0.001576752 0.033950083 0.98375 0.363 2.2224264 2.8010974 0.9919028340080972 0.5907590759075908
# 0.125 4 30
# 0.000846725 0.0016653726 0.038506854 0.99625 0.404 2.1770453 2.7583287 1.0 0.7260726072607261
# 0.125 4 40
# 0.000988949 0.0018287173 0.040911928 1.0 0.44 2.1676219 2.730021 1.0 0.7986798679867987
# 0.125 4 50
# 0.00097189384 0.0015742743 0.040031493 0.99625 0.442 2.1701727 2.7252471 1.0 0.7953795379537953
# 0.25 4 0
# 2.0725508e-09 4.465532e-09 1.9564632e-07 0.02 0.025 3.0909917 3.0909698 0.012145748987854251 0.0231023102310231
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.8721 - accuracy: 0.2525 - val_loss: 2.6700 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5313 - accuracy: 0.3088 - val_loss: 2.4571 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3280 - accuracy: 0.3088 - val_loss: 2.3148 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2057 - accuracy: 0.3088 - val_loss: 2.2647 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1425 - accuracy: 0.3088 - val_loss: 2.3291 - val_accuracy: 0.3000
# 0.25 4 5
# 0.0005153386 0.0013660531 0.012103047 0.30875 0.303 2.8077412 2.893703 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1281 - accuracy: 0.3088 - val_loss: 2.3241 - val_accuracy: 0.3150
# Epoch 2/5
#  - 0s - loss: 2.1148 - accuracy: 0.3350 - val_loss: 2.3385 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.0955 - accuracy: 0.3562 - val_loss: 2.3509 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.0791 - accuracy: 0.3613 - val_loss: 2.3749 - val_accuracy: 0.3100
# Epoch 5/5
#  - 0s - loss: 2.0528 - accuracy: 0.3650 - val_loss: 2.4110 - val_accuracy: 0.2900
# 0.25 4 10
# 0.0005027469 0.0011519361 0.011367463 0.39125 0.273 2.7977831 2.9164793 1.0 0.7260726072607261
# 0.25 4 20
# 0.0009186835 0.0015838521 0.028299838 0.82875 0.39 2.4211912 2.7806394 1.0 0.8712871287128713
# 0.25 4 30
# 0.00097335887 0.0016774182 0.03466359 0.9875 0.39 2.2101905 2.7750375 1.0 0.7227722772277227
# 0.25 4 40
# 0.001037875 0.0019004026 0.039561808 0.9675 0.445 2.2006164 2.722386 1.0 0.9240924092409241
# 0.25 4 50
# 0.001042335 0.0017778844 0.03876758 1.0 0.422 2.1670077 2.752854 1.0 0.7161716171617162
# 0.375 4 0
# 2.3217195e-09 5.5386264e-09 2.1455386e-07 0.0475 0.043 3.0909278 3.0909257 0.08502024291497975 0.07920792079207921
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 1s - loss: 2.8440 - accuracy: 0.2837 - val_loss: 2.6971 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5579 - accuracy: 0.3088 - val_loss: 2.4677 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3677 - accuracy: 0.3088 - val_loss: 2.3458 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.2700 - accuracy: 0.3088 - val_loss: 2.3766 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.1663 - accuracy: 0.3088 - val_loss: 2.3104 - val_accuracy: 0.3000
# 0.375 4 5
# 0.00051402074 0.001313383 0.016062068 0.30875 0.303 2.8060715 2.8448288 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1398 - accuracy: 0.3113 - val_loss: 2.3331 - val_accuracy: 0.3250
# Epoch 2/5
#  - 0s - loss: 2.1250 - accuracy: 0.3288 - val_loss: 2.3029 - val_accuracy: 0.3250
# Epoch 3/5
#  - 0s - loss: 2.1126 - accuracy: 0.3475 - val_loss: 2.3228 - val_accuracy: 0.3250
# Epoch 4/5
#  - 0s - loss: 2.0985 - accuracy: 0.3438 - val_loss: 2.3345 - val_accuracy: 0.3250
# Epoch 5/5
#  - 0s - loss: 2.0962 - accuracy: 0.3462 - val_loss: 2.3826 - val_accuracy: 0.2900
# 0.375 4 10
# 0.00065974 0.0013990458 0.011577322 0.36 0.272 2.8041673 2.917754 1.0 0.7755775577557755
# 0.375 4 20
# 0.0009939604 0.0017163918 0.023093775 0.6925 0.391 2.6108613 2.8094513 1.0 0.900990099009901
# 0.375 4 30
# 0.00096662133 0.0018231734 0.029697753 0.93 0.405 2.3105984 2.7783175 1.0 0.7227722772277227
# 0.375 4 40
# 0.0009552898 0.0017175592 0.032970957 0.99625 0.438 2.1983473 2.7475214 1.0 0.7920792079207921
# 0.375 4 50
# 0.0010210277 0.0018112542 0.037775747 0.9975 0.461 2.1718528 2.7084506 1.0 0.8712871287128713
# 0.5 4 0
# 9.037473e-10 1.2219027e-09 1.0902602e-07 0.0275 0.026 3.0911417 3.0911338 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.9194 - accuracy: 0.2488 - val_loss: 2.6224 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.5659 - accuracy: 0.3088 - val_loss: 2.4985 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.3940 - accuracy: 0.3088 - val_loss: 2.3747 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.3075 - accuracy: 0.3088 - val_loss: 2.3593 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.2174 - accuracy: 0.3088 - val_loss: 2.3402 - val_accuracy: 0.3000
# 0.5 4 5
# 0.00041000824 0.0012912496 0.009411825 0.30875 0.303 2.831088 2.9255478 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.1720 - accuracy: 0.3088 - val_loss: 2.2662 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.1391 - accuracy: 0.3088 - val_loss: 2.3349 - val_accuracy: 0.3300
# Epoch 3/5
#  - 0s - loss: 2.1313 - accuracy: 0.3162 - val_loss: 2.3159 - val_accuracy: 0.3250
# Epoch 4/5
#  - 0s - loss: 2.1252 - accuracy: 0.3325 - val_loss: 2.3474 - val_accuracy: 0.3300
# Epoch 5/5
#  - 0s - loss: 2.1058 - accuracy: 0.3350 - val_loss: 2.3664 - val_accuracy: 0.3000
# 0.5 4 10
# 0.0005175723 0.0013121514 0.01336709 0.345 0.314 2.8042219 2.878269 1.0 0.9405940594059405
# 0.5 4 20
# 0.0007435668 0.0014393766 0.013568634 0.50625 0.299 2.7191834 2.9017003 1.0 0.7260726072607261
# 0.5 4 30
# 0.0010504604 0.0014939464 0.016929995 0.715 0.294 2.5448778 2.897026 0.9959514170040485 0.5313531353135313
# 0.5 4 40
# 0.0010487536 0.0016423465 0.02630633 0.8925 0.401 2.3756988 2.780827 1.0 0.8613861386138614
# 0.5 4 50
# 0.0009292054 0.0016354686 0.027861584 0.96125 0.395 2.2605555 2.7825792 1.0 0.7326732673267327
# 0.625 4 0
# 1.789074e-09 4.131625e-09 1.9578187e-07 0.045 0.039 3.0912213 3.0912373 0.0 0.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.9109 - accuracy: 0.2313 - val_loss: 2.6363 - val_accuracy: 0.3000
# Epoch 2/5
#  - 0s - loss: 2.6400 - accuracy: 0.3088 - val_loss: 2.7281 - val_accuracy: 0.3000
# Epoch 3/5
#  - 0s - loss: 2.5318 - accuracy: 0.3088 - val_loss: 2.5577 - val_accuracy: 0.3000
# Epoch 4/5
#  - 0s - loss: 2.4064 - accuracy: 0.3088 - val_loss: 2.4956 - val_accuracy: 0.3000
# Epoch 5/5
#  - 0s - loss: 2.3137 - accuracy: 0.3088 - val_loss: 2.4371 - val_accuracy: 0.3000
# 0.625 4 5
# 0.00045726993 0.0009805044 0.0058679297 0.30875 0.303 2.9029298 2.9728057 1.0 1.0
# Train on 800 samples, validate on 200 samples
# Epoch 1/5
#  - 0s - loss: 2.2569 - accuracy: 0.3088 - val_loss: 2.3370 - val_accuracy: 0.3250
# Epoch 2/5
#  - 0s - loss: 2.1939 - accuracy: 0.3125 - val_loss: 2.3228 - val_accuracy: 0.3300
# Epoch 3/5
#  - 0s - loss: 2.1674 - accuracy: 0.3200 - val_loss: 2.3950 - val_accuracy: 0.3050
# Epoch 4/5
#  - 0s - loss: 2.1482 - accuracy: 0.3313 - val_loss: 2.3068 - val_accuracy: 0.3300
# Epoch 5/5
#  - 0s - loss: 2.1284 - accuracy: 0.3413 - val_loss: 2.3557 - val_accuracy: 0.3100
# 0.625 4 10
# 0.0005182513 0.0011257026 0.010814546 0.355 0.317 2.8063319 2.9102046 1.0 0.9174917491749175
# 0.625 4 20
# 0.0005147102 0.0014143026 0.015276559 0.38 0.31 2.7934752 2.8684351 1.0 0.8844884488448845
# 0.625 4 30
# 0.0008927307 0.0015155103 0.01518065 0.485 0.317 2.7391067 2.887172 1.0 0.8217821782178217
# 0.625 4 40
# 0.00088520814 0.0015197976 0.017986894 0.51375 0.316 2.6833332 2.8585718 1.0 0.7920792079207921
# 0.625 4 50
# 0.0010677191 0.0018117804 0.017589828 0.525 0.283 2.6524715 2.8912966 1.0 0.7260726072607261

# %%
print(pred_val)
print(xgb1.predict(X_val_tfidf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2d007bc34803> in <module>
# ----> 1 print(pred_val)
#       2 print(xgb1.predict(X_val_tfidf))
#
# NameError: name 'pred_val' is not defined

# %%
from keras.layers import Dropout, Dense, GRU, Embedding
from keras.models import Sequential
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn import metrics
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.datasets import fetch_20newsgroups
