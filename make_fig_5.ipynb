# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.special import comb

# %%
fig = plt.figure(figsize=(10, 10))
n_features = 25
orders = range(1, n_features)
n_intx = np.array([comb(n_features, k) for k in orders])
n_samples = 10000
markers = ['+', '.', '*', 'o', '^', 's', 'p']
for i, dropout_p in enumerate([0.0, 0.125, 0.25, 0.375, 0.5, 0.625, 0.75]):
    lrs = np.array([(1.-dropout_p)**k for k in orders])
    ess = np.array([n_samples*(0.5**(k-1)) for k in orders])
    plt.semilogy(orders, n_intx*lrs, label='{:.3f}'.format(dropout_p), marker=markers[i])
plt.xlabel("Interaction Order", fontsize=30)
plt.ylabel("$r(k)|\mathcal{H}_k|$", fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=18)
plt.tight_layout()
plt.savefig("results/hypothesis_space_full.pdf", dpi=300)

# %%
# Inset of 1-5 region.
fig = plt.figure(figsize=(10, 10))
n_features = 25
orders = range(1, 5)
n_intx = np.array([comb(n_features, k) for k in orders])
n_samples = 10000
markers = ['+', '.', '*', 'o', '^', 's', 'p']
for i, dropout_p in enumerate([0.0, 0.125, 0.25, 0.375, 0.5, 0.625, 0.75]):
    lrs = np.array([(1.-dropout_p)**k for k in orders])
    ess = np.array([n_samples*(0.5**(k-1)) for k in orders])
    plt.plot(orders, n_intx*lrs, label='{:.3f}'.format(dropout_p), marker=markers[i])
plt.xlabel("Interaction Order", fontsize=30)
plt.ylabel("$r(k)|\mathcal{H}_k|$", fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=18)
plt.tight_layout()
plt.savefig("results/hypothesis_space_inset.pdf", dpi=300)
